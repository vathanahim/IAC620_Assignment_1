# %% [markdown]
# ##### Environment was installed by going to the anaconda website and downloading anaconda. Then anaconda was launched. In the environment tab, the create button was pressed in order to create the new working environment. Subsequently, pip was used to install a list of python libraries.

# %%
import cv2 as cv
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img_apple = cv.imread("data/fuji_apple_001.jpg")
img_pear = cv.imread("data/spanish_pear_001.jpg")
img_watermelon = cv.imread("data/watermelon_001.jpg")

# img_apple = cv.cvtColor(img_apple, cv.COLOR_BGR2RGB)
# img_pear = cv.cvtColor(img_pear, cv.COLOR_BGR2RGB)
# img_watermelon = cv.cvtColor(img_watermelon, cv.COLOR_BGR2RGB)

# %%
img_list = [img_apple, img_pear, img_watermelon]

title = ["apple","pear","watermelon"]

color_channel = ["B_channel", "G_channel", "R_channel"]

num = 0
for i in img_list:
    n = 0
    #split color channel of each image by B, G, R
    for j in cv.split(i):
        plt.figure()
        plt.imshow(j)
        plt.title(title[num]+"_"+color_channel[n])
        n = n+1
    num = num+1

# %%
img_list_gray = []
for i in img_list:
    img = cv.cvtColor(i, cv.COLOR_BGR2GRAY)
    img_list_gray.append(img)
    plt.figure()
    plt.imshow(img, cmap='gray')
    plt.title("dimension {}".format(img.shape))

# %%
#helper function

def img_resize(width, height, img):
    dim = (width, height)
    resized = cv.resize(img, dim, interpolation = cv.INTER_AREA)
    return resized

def img_blocks(img):
    blocks = np.array([img[i:i+8, j:j+8] for j in range(0,256,8) for i in range(0,256,8)])
    return blocks

# %%
gray_imgresize = []

for i in img_list_gray:
    temp_img = img_resize(344, 256, i)
    gray_imgresize.append(temp_img)
    
img_list_resize = []
for i in img_list:
    temp_img = img_resize(256, 256, i)
    img_list_resize.append(temp_img)

# %%
for i in gray_imgresize:
    plt.figure()
    plt.imshow(i, cmap='gray')
    plt.title("resized gray image dimension {}".format(i.shape))

# %%
img_one = gray_imgresize[0]

# %%
# d = np.array([[[1, 2], [3, 4], [5,9]], [[5, 6], [7, 8], [10,12]], [[1, 4], [9, 8], [9,12]]])
# d.shape
# d[0:2,0:2]
# Out:
# (3, 3, 2)

# %%
blocks[0]
# Out:
# array([[165, 161, 166, 167, 172, 171, 178, 179],
#        [163, 165, 169, 172, 169, 173, 177, 178],
#        [161, 168, 170, 176, 174, 178, 176, 177],
#        [162, 166, 166, 175, 176, 177, 176, 179],
#        [166, 167, 169, 173, 174, 176, 179, 180],
#        [165, 167, 170, 172, 176, 180, 182, 180],
#        [169, 171, 173, 175, 179, 180, 181, 181],
#        [167, 169, 171, 174, 176, 177, 179, 182]], dtype=uint8)

# %%
block_dic = {}
for i in len(blocks)
   block_dic["feature.{}".format(i)] = block
# Out:
# [167 165 164] [164 162 160] [170 168 167] [174 172 171] [179 174 173] [184 179 178] [181 176 175] [184 179 178]
# [172 170 169] [175 173 172] [179 177 176] [182 179 178] [184 179 178] [190 185 184] [195 190 189] [196 191 190]

# %%
def image_part_plotter(images_list, offset):
    fig = plt.figure(figsize=(12, 12))
    columns = 8
    rows = 8
    # ax enables access to manipulate each of subplots
    ax = []
    for i in range(columns*rows):
        # create subplot and append to ax
        img = mpimg.imread(images_list[i+offset])
        ax.append(fig.add_subplot(rows, columns, i+1))
        ax[-1].set_title(“image part number “ + str(i+1))
        plt.imshow(img)
    plt.show() # Render the plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-5ef7af0d3577> in <module>
#       5 for i in range(columns*rows):
#       6     # create subplot and append to ax
# ----> 7     img = mpimg.imread(blocks[i+0])
#       8     ax.append(fig.add_subplot(rows, columns, i+1))
#       9     ax[-1].set_title("image part number" + str(i+1))
#
# ~/opt/anaconda3/envs/MSIA/lib/python3.7/site-packages/matplotlib/image.py in imread(fname, format)
#    1474             with urllib.request.urlopen(fname) as response:
#    1475                 return imread(response, format=ext)
# -> 1476     with img_open(fname) as image:
#    1477         return (_pil_png_to_float_array(image)
#    1478                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/opt/anaconda3/envs/MSIA/lib/python3.7/site-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     115         try:
#     116             try:
# --> 117                 self._open()
#     118             except (
#     119                 IndexError,  # end of data
#
# ~/opt/anaconda3/envs/MSIA/lib/python3.7/site-packages/PIL/PngImagePlugin.py in _open(self)
#     636     def _open(self):
#     637
# --> 638         if not _accept(self.fp.read(8)):
#     639             raise SyntaxError("not a PNG file")
#     640         self.__fp = self.fp
#
# AttributeError: 'numpy.ndarray' object has no attribute 'read'

# %%
img = mpimg.imread(blocks)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-19edae84a0d2> in <module>
# ----> 1 img = mpimg.imread(blocks)
#
# ~/opt/anaconda3/envs/MSIA/lib/python3.7/site-packages/matplotlib/image.py in imread(fname, format)
#    1474             with urllib.request.urlopen(fname) as response:
#    1475                 return imread(response, format=ext)
# -> 1476     with img_open(fname) as image:
#    1477         return (_pil_png_to_float_array(image)
#    1478                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/opt/anaconda3/envs/MSIA/lib/python3.7/site-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     115         try:
#     116             try:
# --> 117                 self._open()
#     118             except (
#     119                 IndexError,  # end of data
#
# ~/opt/anaconda3/envs/MSIA/lib/python3.7/site-packages/PIL/PngImagePlugin.py in _open(self)
#     636     def _open(self):
#     637
# --> 638         if not _accept(self.fp.read(8)):
#     639             raise SyntaxError("not a PNG file")
#     640         self.__fp = self.fp
#
# AttributeError: 'numpy.ndarray' object has no attribute 'read'
